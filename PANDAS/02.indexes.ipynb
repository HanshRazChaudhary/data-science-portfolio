# %%
people = {
    'first' : ['Ram', 'Shyam', 'Binod'],
    'last' : ['Das', 'Bahadur', 'Chaudhary'],
    'email' : ['ramdas@gmail.com', 'shyambdr@gmail.com', 'binodchy@gmail.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first       last               email
# 0    Ram        Das    ramdas@gmail.com
# 1  Shyam    Bahadur  shyambdr@gmail.com
# 2  Binod  Chaudhary  binodchy@gmail.com

# %%
# Setting Our Own Indexes [Email As An Index]
df.set_index('email', inplace = True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df
# Out:
#                     first       last
# email
# ramdas@gmail.com      Ram        Das
# shyambdr@gmail.com  Shyam    Bahadur
# binodchy@gmail.com  Binod  Chaudhary

# %%
df.loc['shyambdr@gmail.com']
# Out:
# first      Shyam
# last     Bahadur
# Name: shyambdr@gmail.com, dtype: object

# %%
# Reseting The Index:
df.reset_index(inplace = True)

# %%
df
# Out:
#                 email  first       last
# 0    ramdas@gmail.com    Ram        Das
# 1  shyambdr@gmail.com  Shyam    Bahadur
# 2  binodchy@gmail.com  Binod  Chaudhary
